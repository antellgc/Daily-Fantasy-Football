# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.misc import comb
# %matplotlib inline

# %% [markdown]
# # Potential Combinations

# %%
qb_combs = comb(30,1)
dst_combs = comb(30,1)
rb_combs = comb(90,2)
wr_combs = comb(120,3)
te_combs = comb(60,1)
flex_combs = comb(200,1)

p = qb_combs * dst_combs * rb_combs * wr_combs \
    * te_combs * flex_combs
print p
# Out:
# 1.214745336e+16

# %% [markdown]
# # ESPN Data Scraping -- player projections

# %%
from bs4 import BeautifulSoup
import requests

url_string = "http://games.espn.com/ffl/tools/projections?&scoringPeriodId=1&seasonId=2017"


def get_projection_df(url_string):
    page = requests.get(url_string)
    soup = BeautifulSoup(page.content, 'html.parser')
    stats_table = soup.find('table', {'id': 'playertable_0'})
    row_stats = stats_table.findAll('tr',  {'class': ['playerTableBgRowSubhead','pncPlayerRow']})
    total_data = []
    for row in row_stats:
        data = [td.text.replace(u'\xa0',' ').encode('utf-8').strip() for td in row.find_all('td') if td.text]
        total_data.append(data)
    df = pd.DataFrame(total_data)
    df.rename(columns=df.iloc[0], inplace=True)
    df = df.reindex(df.index.drop(0))
    return df[['PLAYER, TEAM POS','PTS']]

projection_df = get_projection_df(url_string)
projection_df.head(10)
# Out:
#               PLAYER, TEAM POS   PTS
# 1         Le'Veon Bell, Pit RB  25.2
# 2   David Johnson*, Ari RB  IR  23.4
# 3             Tom Brady, NE QB  19.8
# 4        Cam Newton, Car QB  Q  19.6
# 5       Russell Wilson, Sea QB  19.5
# 6         Aaron Rodgers, GB QB  19.2
# 7        Antonio Brown, Pit WR  19.1
# 8      Ezekiel Elliott, Dal RB    19
# 9     Matthew Stafford, Det QB  18.6
# 10        Tyrod Taylor, Buf QB  18.4

# %%
projection_df['TEAM'] = projection_df['PLAYER, TEAM POS'].apply(lambda y: y.split(',')[1])

projection_df
# Out:
#                PLAYER, TEAM POS   PTS         TEAM
# 1              Tom Brady, NE QB  24.9        NE QB
# 2          Aaron Rodgers, GB QB  22.5        GB QB
# 3        Russell Wilson, Sea QB  22.2       Sea QB
# 4             Drew Brees, NO QB  22.1        NO QB
# 5             Matt Ryan, Atl QB  21.9       Atl QB
# 6            Derek Carr, Oak QB  21.3       Oak QB
# 7            Cam Newton, Car QB  21.3       Car QB
# 8         Antonio Brown, Pit WR  20.8       Pit WR
# 9          Le'Veon Bell, Pit RB  20.5       Pit RB
# 10       Julio Jones, Atl WR  Q  19.8    Atl WR  Q
# 11        Carson Palmer, Ari QB  19.5       Ari QB
# 12          Jordy Nelson, GB WR  19.3        GB WR
# 13        Rob Gronkowski, NE TE  19.2        NE TE
# 14        Jameis Winston, TB QB    19        TB QB
# 15         Kirk Cousins, Wsh QB  18.6       Wsh QB
# 16           Joe Flacco, Bal QB  18.2       Bal QB
# 17           A.J. Green, Cin WR    18       Cin WR
# 18   Ben Roethlisberger, Pit QB  17.9       Pit QB
# 19     Larry Fitzgerald, Ari WR  17.8       Ari WR
# 20            Mike Evans, TB WR  17.8        TB WR
# 21        Philip Rivers, LAC QB  17.8       LAC QB
# 22        Michael Thomas, NO WR  17.8        NO WR
# 23          Eli Manning, NYG QB  17.6       NYG QB
# 24      Doug Baldwin, Sea WR  Q  17.6    Sea WR  Q
# 25       Trevor Siemian, Den QB  17.4       Den QB
# 26       Marcus Mariota, Ten QB  17.3       Ten QB
# 27         Tyrod Taylor, Buf QB  17.2       Buf QB
# 28         Brandin Cooks, NE WR  17.2        NE WR
# 29      DeAndre Hopkins, Hou WR    17       Hou WR
# 30     Matthew Stafford, Det QB    17       Det QB
# 31      Ezekiel Elliott, Dal RB  16.9       Dal RB
# 32     Demaryius Thomas, Den WR  16.8       Den WR
# 33  Michael Crabtree, Oak WR  Q  16.7    Oak WR  Q
# 34            Alex Smith, KC QB  16.6        KC QB
# 35      Devonta Freeman, Atl RB  16.5       Atl RB
# 36     Emmanuel Sanders, Den WR  16.3       Den WR
# 37         Dak Prescott, Dal QB  16.3       Dal QB
# 38         Amari Cooper, Oak WR  16.3       Oak WR
# 39      Greg Olsen*, Car TE  IR  16.1   Car TE  IR
# 40         Carson Wentz, Phi QB  15.9       Phi QB

# %%
dfpart = pd.DataFrame(df_week1['Name'].apply(lambda x: x
                       .replace('.', '')
                       .replace('Jr', '')
                       .replace('Sr', '')
                       .replace('-', '')
                       .replace('\'', '')
                       .replace('II', '').upper().split(', ', maxsplit=1)[::-1]).values.tolist(), 
                      columns=['Firstname', 'Lastname'])
